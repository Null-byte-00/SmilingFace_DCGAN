# %%
from model import GAN
from train import train

gan = GAN()
train(gan, epochs=36, verbose=False)
# Out:
# epoch 3 Discriminator loss: 0.1808454841375351 Generator loss: 4.316741943359375
# epoch 6 Discriminator loss: 0.055417198687791824 Generator loss: 5.237893581390381
# epoch 9 Discriminator loss: 0.030946003273129463 Generator loss: 6.286107063293457
# epoch 12 Discriminator loss: 0.021906942129135132 Generator loss: 8.228336334228516
# epoch 15 Discriminator loss: 0.01706486940383911 Generator loss: 8.19401741027832
# epoch 18 Discriminator loss: 0.02632869966328144 Generator loss: 8.822402000427246
# epoch 21 Discriminator loss: 0.023670215159654617 Generator loss: 8.768973350524902
# epoch 24 Discriminator loss: 0.04121917113661766 Generator loss: 8.499874114990234
# epoch 27 Discriminator loss: 0.03570541366934776 Generator loss: 7.885575771331787
# epoch 30 Discriminator loss: 5.5146221711765975e-05 Generator loss: 100.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 from train import train
#       4 gan = GAN()
# ----> 5 train(gan, epochs=36, verbose=False)
#
# File D:\programs\python\datasci_ai\DCGAN\train.py:19, in train(model, dataset, epochs, verbose, device)
#      17     print(f'Batch {i + 1}/{len(dataloader)} Epoch {epoch + 1}/{epochs}')
#      18 x = x.to(device)
# ---> 19 loss_d, loss_g = model.train(x.clone().detach(), verbose=verbose)
#      20 d_losses.append(loss_d)
#      21 g_losses.append(loss_g)
#
# File D:\programs\python\datasci_ai\DCGAN\model.py:114, in GAN.train(self, x, verbose)
#     113 def train(self, x, verbose=False):
# --> 114     loss1 = self.train_D(x)
#     115     loss2 = self.train_G()
#     116     if verbose:
#
# File D:\programs\python\datasci_ai\DCGAN\model.py:101, in GAN.train_D(self, x)
#      99 z = torch.randn(1, self.latent_dim).to(self.generator.linear.weight.device) # noise
#     100 g_output = self.generator(z)
# --> 101 d_fake_output = self.discriminator(g_output)
#     102 loss_fake = self.loss(d_fake_output, torch.zeros_like(d_fake_output))
#     104 d_real_output = self.discriminator(x)
#
# File D:\programs\python\datasci_ai\DCGAN\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File D:\programs\python\datasci_ai\DCGAN\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File D:\programs\python\datasci_ai\DCGAN\model.py:67, in Discrimintor.forward(self, x)
#      66 def forward(self, x):
# ---> 67     return self.stack(x)
#
# File D:\programs\python\datasci_ai\DCGAN\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File D:\programs\python\datasci_ai\DCGAN\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File D:\programs\python\datasci_ai\DCGAN\venv\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File D:\programs\python\datasci_ai\DCGAN\venv\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File D:\programs\python\datasci_ai\DCGAN\venv\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File D:\programs\python\datasci_ai\DCGAN\venv\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
from model import GAN
from torchvision import transforms
import matplotlib.pyplot as plt

model = GAN()

model.generator.load("models/26_2/generator.pth")

to_pil = transforms.ToPILImage()
fig = plt.figure(figsize=(11, 8))

columns = 5
rows = 2

for i in range(1,rows*columns + 1):
    fig.add_subplot(rows, columns, i)
    out = model.generate().detach().cpu().squeeze(0)
    img = to_pil(out)
    plt.imshow(img, cmap='gray')

plt.show()
